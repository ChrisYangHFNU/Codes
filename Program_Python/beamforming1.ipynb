# %%
import numpy as np
from   matplotlib import pyplot as plt

N = 8      # 天线数量

theta = np.arange(0.000001,2*np.pi-0.0000001,0.01)

psi = np.pi*np.cos(theta)

r = np.abs(np.sin(N*psi/2)/np.sin(psi/2))/N

plt.figure()
plt.polar(theta,r)
plt.show()

# %% [markdown]
# $$\begin{align*}&\frac{1}{N}\sum_{k=0}^{N-1}\mathrm{e}^{jk\psi} \\
# & = \frac{1}{N}\frac{1-\mathrm{e}^{jN\psi}}{1-\mathrm{e}^{j\psi}}\\
# & = \frac{1}{N}\frac{\mathrm{e}^{jN\psi/2}}{\mathrm{e}^{j\psi/2}}\frac{\mathrm{e}^{-jN\psi/2}-\mathrm{e}^{jN\psi/2}}{\mathrm{e}^{-j\psi/2}-\mathrm{e}^{j\psi/2}}\\
# & = \frac{\mathrm{e}^{jN\psi/2}}{\mathrm{e}^{j\psi/2}}\frac{\sin(N\psi/2)}{N\sin(\psi/2)}
# \end{align*}$$
# $\psi=\dfrac{2\pi d \cos(\theta)}{\lambda} $

# %%
import numpy as np
from   matplotlib import pyplot as plt

N = 16

theta0 = np.pi/6
psi0 = np.pi*np.cos(theta0)

theta = np.arange(0.000001,2*np.pi-0.0000001,0.01)

psi = np.pi*np.cos(theta)

r = np.abs(np.sin(N*(psi-psi0)/2)/np.sin((psi-psi0)/2))/N

plt.figure()
plt.polar(theta,r)
plt.show()

# %%
0.52001/np.pi*180
# Out:
# 29.794378304597934
